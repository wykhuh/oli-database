# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import math

# %%
def log_df(df, limit=5):
    print(df.shape)
    return df.head(limit)

int_dtype = {'playlist_position': 'Int64', 'price': 'Int64',
             'serial_number':'Int64', 'product_id': 'Int64'}

# %%
def fetch_content(url):
    # print(url)
    page = requests.get(url)
    return BeautifulSoup(page.content, "html.parser")


def calculate_page_count(htmlContent):
    count_container = htmlContent.find("span", class_="toolbar-number")

    if count_container:
        count = int(count_container.text)
        return math.ceil(count/24)
    else:
        return 0

# %%
def process_title(title):
    matches = re.findall("\\(.*?([LX][A-Za-z0-9- ]+)\\)", title)
    if matches[0]:
        parts = matches[0].split(' ')
        model = parts[0]
        serial_match = re.search("[0-9]+", parts[-1])
        serial_number = int(serial_match[0])

        return {"model": model, 'serial_number':serial_number}

def process_list_content(htmlContent):
    units = []

    items = htmlContent.find_all("div", class_="product-item-details")
    for item in items:
        link = item.find('a', class_='product-item-link')
        href = link['href']
        title = link.text.strip()

        title_data = process_title(title)

        price_container = item.find('span', class_='price-wrapper')
        price = price_container['data-price-amount']

        details_content = fetch_content(href)
        details_data = process_details_content(details_content)

        id_container = item.find("div", class_="price-final_price")
        product_id = id_container["data-product-id"]

        units.append({
            "listing_title": title,
            "listing_url": href,
            "model": title_data['model'],
            "serial_number": title_data['serial_number'],
            "price": int(price),
            "video_id": details_data['video_id'],
            "product_id": int(product_id)
        })

    return units

def process_details_content(htmlContent):
    embed_container = htmlContent.find('div', class_ = 'embed-container')
    iframe = embed_container.find('iframe')
    parts = iframe['src'].split('/')
    params = parts[-1].split('?')

    id_container = htmlContent.find("div", class_="price-final_price")
    product_id = id_container["data-product-id"]


    return {'video_id': params[0], "product_id": int(product_id)}

# %%
OLI_URL = "https://theukulelesite.com/shop-by/brand/oli.html"
html_countent = fetch_content(OLI_URL)
# Out:
# https://theukulelesite.com/shop-by/brand/oli.html

# %%
units = []

units = process_list_content(html_countent)

# %%
page_count = calculate_page_count(html_countent)

for count in range(page_count):
    if count == 0:
        continue

    page_url = f'{OLI_URL}?p={count + 1}'
    html_countent = fetch_content(page_url)
    units = units + process_list_content(html_countent)

# %%
df = pd.DataFrame(units)
log_df(df)
# Out:
# (62, 6)
#                                        listing_title  \
# 0     'Oli Redwood Rosewood Concert (X2-CRR-SE 1665)
# 1  'Oli Port Orford Cedar Myrtle Concert Gloss (L...
# 2            'Oli Myrtle Concert Gloss (L1-CMR 1570)
# 3       'Oli Redwood Rosewood Tenor (X2-TRR-SE 1690)
# 4  'Oli Sinker Cypress Quilted Maple LE Concert (...
#
#                                          listing_url        model  \
# 0  https://theukulelesite.com/shop-by/brand/oli/o...    X2-CRR-SE
# 1  https://theukulelesite.com/shop-by/brand/oli/o...   L1SP-CCPMR
# 2  https://theukulelesite.com/shop-by/brand/oli/o...       L1-CMR
# 3  https://theukulelesite.com/shop-by/brand/oli/o...    X2-TRR-SE
# 4  https://theukulelesite.com/shop-by/brand/oli/o...  L2-CSCQM-BK
#
#    serial_number  price     video_id
# 0           1665   1395  P8TOa1_NZxI
# 1           1542    895  gsqmlrAh3m4
# 2           1570    795  WGt5K3woqho
# 3           1690   1495  ecDhE4DQ0jk
# 4           1750   1395  jc6vNNrlYnk

# %%
df.to_csv('../raw_data/oli_listings.csv', index=False)

# %% [markdown]
# ## testing functions

# %%
titles = [
    'Oli Redwood Rosewood Concert (X2-CRR-SE 1665)',
    'Oli Redwood Rosewood Concert (2024 X2-CRR-SE 1665)',
    'Oli Redwood Rosewood Concert (X2-CRR-SE 1665B)',
    'Oli Redwood Rosewood Concert (X2-CRR-SE Moon Bay 1665)'
]

for title in titles:
    print(process_title(title))
# Out:
# {'model': 'X2-CRR-SE', 'serial_number': 1665}
# {'model': 'X2-CRR-SE', 'serial_number': 1665}
# {'model': 'X2-CRR-SE', 'serial_number': 1665}
# {'model': 'X2-CRR-SE', 'serial_number': 1665}

# %%
from datetime import datetime

current_dateTime = datetime.now()

# 2024-02-28T22:45:18Z

date_time = current_dateTime.strftime("%Y-%m-%d %H:%M:%S")
print(date_time)
# Out:
# 2025-10-03 17:34:57

# %% [markdown]
# ## find sold listings

# %%
df = pd.read_csv('../raw_data/oli_listings.csv', dtype=int_dtype)
log_df(df)
# Out:
# (71, 10)
#                                        listing_title  \
# 0     'Oli Redwood Rosewood Concert (X2-CRR-SE 1665)
# 1  'Oli Port Orford Cedar Myrtle Concert Gloss (L...
# 2            'Oli Myrtle Concert Gloss (L1-CMR 1570)
# 3       'Oli Redwood Rosewood Tenor (X2-TRR-SE 1690)
# 4  'Oli Sinker Cypress Quilted Maple LE Concert (...
#
#                                          listing_url        model  \
# 0  https://theukulelesite.com/shop-by/brand/oli/o...    X2-CRR-SE
# 1  https://theukulelesite.com/shop-by/brand/oli/o...   L1SP-CCPMR
# 2  https://theukulelesite.com/shop-by/brand/oli/o...       L1-CMR
# 3  https://theukulelesite.com/shop-by/brand/oli/o...    X2-TRR-SE
# 4  https://theukulelesite.com/shop-by/brand/oli/o...  L2-CSCQM-BK
#
#    serial_number  price     video_id           date_added  \
# 0           1665   1395  P8TOa1_NZxI  2025-10-03 12:00:00
# 1           1542    895  gsqmlrAh3m4  2025-10-03 12:00:00
# 2           1570    795  WGt5K3woqho  2025-10-03 12:00:00
# 3           1690   1495  ecDhE4DQ0jk  2025-10-03 12:00:00
# 4           1750   1395  jc6vNNrlYnk  2025-10-03 12:00:00
#
#              date_sold  serial_number_y  product_id
# 0  2025-10-06 14:40:04              NaN         NaN
# 1  2025-10-06 14:40:04              NaN         NaN
# 2                  NaN              NaN         NaN
# 3  2025-10-07 04:47:22              NaN         NaN
# 4                  NaN              NaN         NaN

# %%
site_serials = [1750]

# %%
temp = df[pd.isna(df['date_sold'])]

temp = temp[~temp['serial_number'].isin(site_serials)]

log_df(temp)
# Out:
# (58, 8)
#                                        listing_title  \
# 2            'Oli Myrtle Concert Gloss (L1-CMR 1570)
# 3       'Oli Redwood Rosewood Tenor (X2-TRR-SE 1690)
# 5  'Oli Sinker Cypress Flame Maple Tenor (L2-TSCF...
# 6                   'Oli Acacia Concert (X1-CA 1843)
# 7                  'Oli Acacia Baritone (X1-BA 1757)
#
#                                          listing_url        model  \
# 2  https://theukulelesite.com/shop-by/brand/oli/o...       L1-CMR
# 3  https://theukulelesite.com/shop-by/brand/oli/o...    X2-TRR-SE
# 5  https://theukulelesite.com/shop-by/brand/oli/o...  L2-TSCFM-BK
# 6  https://theukulelesite.com/shop-by/brand/oli/o...        X1-CA
# 7  https://theukulelesite.com/shop-by/brand/oli/o...        X1-BA
#
#    serial_number  price     video_id           date_added date_sold
# 2           1570    795  WGt5K3woqho  2025-10-03 12:00:00       NaN
# 3           1690   1495  ecDhE4DQ0jk  2025-10-03 12:00:00       NaN
# 5           1675   1495  lpF2AYhpI9g  2025-10-03 12:00:00       NaN
# 6           1843    895  qI4e8Hm2EWk  2025-10-03 12:00:00       NaN
# 7           1757   1095  RlGo3xYKAIQ  2025-10-03 12:00:00       NaN

# %% [markdown]
# # add product id

# %%
df = pd.read_csv('../raw_data/oli_listings.csv', dtype=int_dtype)
log_df(df)
# Out:
# (83, 9)
#                                        listing_title  \
# 0     'Oli Redwood Rosewood Concert (X2-CRR-SE 1665)
# 1  'Oli Port Orford Cedar Myrtle Concert Gloss (L...
# 2            'Oli Myrtle Concert Gloss (L1-CMR 1570)
# 3       'Oli Redwood Rosewood Tenor (X2-TRR-SE 1690)
# 4  'Oli Sinker Cypress Quilted Maple LE Concert (...
#
#                                          listing_url        model  \
# 0  https://theukulelesite.com/shop-by/brand/oli/o...    X2-CRR-SE
# 1  https://theukulelesite.com/shop-by/brand/oli/o...   L1SP-CCPMR
# 2  https://theukulelesite.com/shop-by/brand/oli/o...       L1-CMR
# 3  https://theukulelesite.com/shop-by/brand/oli/o...    X2-TRR-SE
# 4  https://theukulelesite.com/shop-by/brand/oli/o...  L2-CSCQM-BK
#
#    serial_number  price     video_id           date_added  \
# 0           1665   1395  P8TOa1_NZxI  2025-10-03 12:00:00
# 1           1542    895  gsqmlrAh3m4  2025-10-03 12:00:00
# 2           1570    795  WGt5K3woqho  2025-10-03 12:00:00
# 3           1690   1495  ecDhE4DQ0jk  2025-10-03 12:00:00
# 4           1750   1395  jc6vNNrlYnk  2025-10-03 12:00:00
#
#              date_sold  product_id
# 0  2025-10-06 14:40:04       14256
# 1  2025-10-06 14:40:04        <NA>
# 2                  NaN       14254
# 3  2025-10-07 04:47:22        <NA>
# 4  2025-10-09 21:20:14       14251

# %%
df2 = pd.read_csv('../raw_data/draft/oli_listings_3.csv', usecols=['serial_number', 'product_id'])
log_df(df2)
# Out:
# (56, 2)
#    serial_number  product_id
# 0           1572       14285
# 1           1608       14283
# 2           1790       14259
# 3           1777       14257
# 4           1570       14254

# %%
foo = df.merge(df2, how='left', on='serial_number')
foo['product_id'] = foo['product_id'].astype('Int64')
log_df(foo)
# Out:
# (71, 9)
#                                        listing_title  \
# 0     'Oli Redwood Rosewood Concert (X2-CRR-SE 1665)
# 1  'Oli Port Orford Cedar Myrtle Concert Gloss (L...
# 2            'Oli Myrtle Concert Gloss (L1-CMR 1570)
# 3       'Oli Redwood Rosewood Tenor (X2-TRR-SE 1690)
# 4  'Oli Sinker Cypress Quilted Maple LE Concert (...
#
#                                          listing_url        model  \
# 0  https://theukulelesite.com/shop-by/brand/oli/o...    X2-CRR-SE
# 1  https://theukulelesite.com/shop-by/brand/oli/o...   L1SP-CCPMR
# 2  https://theukulelesite.com/shop-by/brand/oli/o...       L1-CMR
# 3  https://theukulelesite.com/shop-by/brand/oli/o...    X2-TRR-SE
# 4  https://theukulelesite.com/shop-by/brand/oli/o...  L2-CSCQM-BK
#
#    serial_number  price     video_id           date_added  \
# 0           1665   1395  P8TOa1_NZxI  2025-10-03 12:00:00
# 1           1542    895  gsqmlrAh3m4  2025-10-03 12:00:00
# 2           1570    795  WGt5K3woqho  2025-10-03 12:00:00
# 3           1690   1495  ecDhE4DQ0jk  2025-10-03 12:00:00
# 4           1750   1395  jc6vNNrlYnk  2025-10-03 12:00:00
#
#              date_sold  product_id
# 0  2025-10-06 14:40:04        <NA>
# 1  2025-10-06 14:40:04        <NA>
# 2                  NaN       14254
# 3  2025-10-07 04:47:22        <NA>
# 4                  NaN       14251

# %%
foo.to_csv('../raw_data/oli_listings.csv', index=False)

# %% [markdown]
# # add video id and product id

# %%
df = pd.read_csv('../raw_data/oli_listings.csv', dtype=int_dtype)
log_df(df)
# Out:
# (83, 9)
#                                        listing_title  \
# 0     'Oli Redwood Rosewood Concert (X2-CRR-SE 1665)
# 1  'Oli Port Orford Cedar Myrtle Concert Gloss (L...
# 2            'Oli Myrtle Concert Gloss (L1-CMR 1570)
# 3       'Oli Redwood Rosewood Tenor (X2-TRR-SE 1690)
# 4  'Oli Sinker Cypress Quilted Maple LE Concert (...
#
#                                          listing_url        model  \
# 0  https://theukulelesite.com/shop-by/brand/oli/o...    X2-CRR-SE
# 1  https://theukulelesite.com/shop-by/brand/oli/o...   L1SP-CCPMR
# 2  https://theukulelesite.com/shop-by/brand/oli/o...       L1-CMR
# 3  https://theukulelesite.com/shop-by/brand/oli/o...    X2-TRR-SE
# 4  https://theukulelesite.com/shop-by/brand/oli/o...  L2-CSCQM-BK
#
#    serial_number  price     video_id           date_added  \
# 0           1665   1395  P8TOa1_NZxI  2025-10-03 12:00:00
# 1           1542    895  gsqmlrAh3m4  2025-10-03 12:00:00
# 2           1570    795  WGt5K3woqho  2025-10-03 12:00:00
# 3           1690   1495  ecDhE4DQ0jk  2025-10-03 12:00:00
# 4           1750   1395  jc6vNNrlYnk  2025-10-03 12:00:00
#
#              date_sold  product_id
# 0  2025-10-06 14:40:04       14256
# 1  2025-10-06 14:40:04        <NA>
# 2                  NaN       14254
# 3  2025-10-07 04:47:22        <NA>
# 4  2025-10-09 21:20:14       14251

# %%
for i, row in df.iterrows():
    if pd.isna(row['video_id']):
        details_content = fetch_content(row['listing_url'])
        details_data = process_details_content(details_content)
        df.loc[i, 'video_id'] = details_data['video_id']

    if pd.isna(row['product_id']):
        details_content = fetch_content(row['listing_url'])
        details_data = process_details_content(details_content)
        df.loc[i, 'product_id'] = details_data['product_id']

# %%
df.to_csv('../raw_data/oli_listings.csv', index=False)

# %% [markdown]
# # key moments

# %%
content = fetch_content('https://www.youtube.com/watch?v=9dtlhufQk84')

# %%
content.find_all('a' )
# Out:
